# %% [markdown]
# # Climate Hackathon: Energy costs:
#
#
# to do : grab this sub df from data
#
# southeastern states:
# Alabama	5,024,279	4,779,736	+5.12%	50,645 sq mi (131,171 km2)	99.2/sq mi (38.3/km2)
# Arkansas[a]	3,011,524	2,915,918	+3.28%	52,035 sq mi (134,771 km2)	57.9/sq mi (22.3/km2)
# Florida	21,538,187	18,801,310	+14.56%	53,625 sq mi (138,887 km2)	401.6/sq mi (155.1/km2)
# Georgia	10,711,908	9,687,653	+10.57%	57,513 sq mi (148,959 km2)	186.3/sq mi (71.9/km2)
# Kentucky[a]	4,505,836	4,339,367	+3.84%	39,486 sq mi (102,269 km2)	114.1/sq mi (44.1/km2)
# Louisiana[a]	4,657,757	4,533,372	+2.74%	43,204 sq mi (111,898 km2)	107.8/sq mi (41.6/km2)
# Maryland[a]	6,177,224	5,773,552	+6.99%	12,407 sq mi (32,134 km2)	497.9/sq mi (192.2/km2)
# Mississippi	2,961,279	2,967,297	−0.20%	46,923 sq mi (121,531 km2)	63.1/sq mi (24.4/km2)
# North Carolina	10,439,388	9,535,483	+9.48%	48,618 sq mi (125,920 km2)	214.7/sq mi (82.9/km2)
# South Carolina	5,118,425	4,625,364	+10.66%	30,061 sq mi (77,857 km2)	170.3/sq mi (65.7/km2)
# Tennessee	6,910,840	6,346,105	+8.90%	41,235 sq mi (106,798 km2)	167.6/sq mi (64.7/km2)
# Virginia[a]	8,631,393	8,001,024	+7.88%	39,490 sq mi (102,279 km2)	218.6/sq mi (84.4/km2)
# West Virginia[a
#
# add justice component
#
# US: sum of all us states,
#
# grab davidson county datat

# %%
#! /usr/bin/env python3
# -*- coding: utf-8 -*-

# Author       : Edgar Carrillo,
# Created      : 2023-11-25
# Last Modified: 2023-11-25
# Vanderbilt University

'''
descrip

data driven report  atha comares several env topics ie drinking water violations
david conuty, TN, SE region, and US

draw a topic and suggestion, make figure, submit caption fig and data to googlke form by midnight dec 1,
applky reports template style

can submit one fig per topic 

succesful visuals:
trasnparent, accesible, comparable, attractive
upload to github, make fig interpretable, provides standardized comparson bewteen nash sate m region and the us
finsl product is clean, consistent, and comprehensie

audiece: env lawyers and social scientists
topic examples: climate, energy, waer, conservation air

renewable eneryg production, projected flood OR heat risk

font: avenir, 
color palette: 

'''
# Out:
# '\ndescrip\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import matplotlib.colors as mcolors
# import colormaps as cmaps 
params = {
    'legend.title_fontsize': 'xx-small',
    'axes.labelsize': 16,
    'font.size': 16,
    'legend.fontsize': 8,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'font.family': 'serif',
    'xtick.direction': 'in',
    'ytick.direction': 'in',
    'xtick.minor.visible': True,
    'ytick.minor.visible': True,
    'xtick.top': True,
    'ytick.right': True,
    'figure.autolayout': True
}
plt.rcParams.update(params)

# %%
#import data here
csv_path               = 'lead-tool-map-data.csv' 
csv_path_TN_counties   = 'lead-tool-map-data-TN-counties.csv' 

#excel_path = '.xlsx'

# %%
df = pd.read_csv(csv_path)
df = pd.read_csv(csv_path_TN_counties)

#df = pd.read_excel(excel_pat, sheet_name = '' )

# %%
df.head()
# Out:
#    Geography ID        Name  Energy Burden (% income)  \
# 0             1     Alabama                         3
# 1             2      Alaska                         3
# 2             4     Arizona                         2
# 3             5    Arkansas                         3
# 4             6  California                         2
#
#    Avg. Annual Energy Cost ($)  Total Households  Household Income  \
# 0                         2065           1888504             73217
# 1                         3364            255173            102603
# 2                         1888           2643430             85417
# 3                         1813           1170544             70182
# 4                         1960          13103373            115504
#
#    Black/ African American (% pop.)  American Indian/ Native Alaskan (% pop.)  \
# 0                                27                                         1
# 1                                 3                                        15
# 2                                 5                                         4
# 3                                15                                         1
# 4                                 6                                         1
#
#    Asian (% pop.)  Native Hawaiian/ Other Pacific Islander (% pop.)  \
# 0               1                                                 0
# 1               6                                                 1
# 2               3                                                 0
# 3               2                                                 0
# 4              15                                                 0
#
#    White Hispanic or Latino (% pop.)  White Non-Hispanic or Latino (% pop.)  \
# 0                                  2                                     65
# 1                                  4                                     60
# 2                                 20                                     54
# 3                                  4                                     72
# 4                                 20                                     37
#
#    Two or More Races (% pop.)  Other Races (% pop.)  \
# 0                           2                     2
# 1                           9                     2
# 2                           7                     7
# 3                           4                     3
# 4                           8                    14
#
#    Less Than High School (% pop.)  High School (% pop.)  \
# 0                              12                    28
# 1                               6                    24
# 2                              10                    20
# 3                              12                    31
# 4                              13                    17
#
#    Associates or Some College (% pop.)  Bachelors or Higher (% pop.)
# 0                                   32                            28
# 1                                   38                            33
# 2                                   36                            34
# 3                                   32                            26
# 4                                   31                            39

# %%
df.describe()
# Out:
#        Geography ID  Energy Burden (% income)  Avg. Annual Energy Cost ($)  \
# count     51.000000                 51.000000                    51.000000
# mean      30.156863                  2.450980                  2094.392157
# std       16.727669                  0.576671                   428.890572
# min        1.000000                  2.000000                  1167.000000
# 25%       17.500000                  2.000000                  1810.000000
# 50%       30.000000                  2.000000                  2041.000000
# 75%       43.000000                  3.000000                  2205.000000
# max       72.000000                  4.000000                  3364.000000
#
#        Total Households  Household Income  Black/ African American (% pop.)  \
# count      5.100000e+01         51.000000                         51.000000
# mean       2.417096e+06      88338.843137                         10.549020
# std        2.551021e+06      16914.894714                          9.392154
# min        2.332310e+05      29624.000000                          1.000000
# 25%        7.504490e+05      79378.000000                          3.500000
# 50%        1.748053e+06      85015.000000                          7.000000
# 75%        2.776401e+06      98484.500000                         14.500000
# max        1.310337e+07     122255.000000                         38.000000
#
#        American Indian/ Native Alaskan (% pop.)  Asian (% pop.)  \
# count                                 51.000000       51.000000
# mean                                   1.450980        4.274510
# std                                    2.968594        5.589556
# min                                    0.000000        0.000000
# 25%                                    0.000000        2.000000
# 50%                                    0.000000        3.000000
# 75%                                    1.000000        5.000000
# max                                   15.000000       38.000000
#
#        Native Hawaiian/ Other Pacific Islander (% pop.)  \
# count                                         51.000000
# mean                                           0.274510
# std                                            1.415322
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                           10.000000
#
#        White Hispanic or Latino (% pop.)  \
# count                          51.000000
# mean                            7.843137
# std                             9.978722
# min                             1.000000
# 25%                             3.000000
# 50%                             5.000000
# 75%                             8.000000
# max                            60.000000
#
#        White Non-Hispanic or Latino (% pop.)  Two or More Races (% pop.)  \
# count                              51.000000                   51.000000
# mean                               66.901961                    4.960784
# std                                18.166183                    3.310352
# min                                 1.000000                    2.000000
# 25%                                57.000000                    3.000000
# 50%                                71.000000                    4.000000
# 75%                                79.000000                    5.500000
# max                                93.000000                   24.000000
#
#        Other Races (% pop.)  Less Than High School (% pop.)  \
# count             51.000000                       51.000000
# mean               3.647059                        8.784314
# std                3.576722                        3.201960
# min                0.000000                        5.000000
# 25%                1.000000                        6.500000
# 50%                3.000000                        8.000000
# 75%                5.000000                       10.000000
# max               19.000000                       24.000000
#
#        High School (% pop.)  Associates or Some College (% pop.)  \
# count             51.000000                            51.000000
# mean              25.254902                            31.764706
# std                3.999216                             3.927280
# min               17.000000                            23.000000
# 25%               23.000000                            30.000000
# 50%               25.000000                            32.000000
# 75%               28.000000                            34.500000
# max               37.000000                            39.000000
#
#        Bachelors or Higher (% pop.)
# count                     51.000000
# mean                      34.156863
# std                        5.658171
# min                       23.000000
# 25%                       30.500000
# 50%                       34.000000
# 75%                       38.000000
# max                       47.000000

# %%
state = 'Name'
burden = 'Energy Burden (% income)'
cost = 'Avg. Annual Energy Cost ($)'

# %%
# fig, ax = plt.subplots(figsize=(10, 10))

# sns.scatterplot(data = df,
#                 x = 'Name',
#                 y = cost,
#                 hue = 'Geography ID',
#                 palette = 'prism'
#                )  # S

# %%
g = sns.PairGrid(df[[state, burden, cost, "Household Income"]], hue="Geography ID")
g.map_upper(sns.regplot)
g.map_lower(sns.residplot)
g.map_diag(plt.hist)
for ax in g.axes.flat:
    plt.setp(ax.get_xticklabels(), rotation=45)
g.add_legend()
g.set(alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /Users/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Users/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Geography ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/q2/2v_9qp1s1n9635tlzjm697gc0000gr/T/ipykernel_25937/1599993583.py in <module>
# ----> 1 g = sns.PairGrid(df[[state, burden, cost, "Household Income"]], hue="Geography ID")
#       2 g.map_upper(sns.regplot)
#       3 g.map_lower(sns.residplot)
#       4 g.map_diag(plt.hist)
#       5 for ax in g.axes.flat:
#
# /Users/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in __init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1319             # to the axes-level functions, while always handling legend creation.
#    1320             # See GH2307
# -> 1321             hue_names = hue_order = categorical_order(data[hue], hue_order)
#    1322             if dropna:
#    1323                 # Filter NA from the list of unique hue names
#
# /Users/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /Users/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Geography ID'
